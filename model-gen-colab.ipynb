# %%
# !pip install transformers datasets evaluate pandas huggingface_hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, pipeline
import torch
from huggingface_hub import login


login(token="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")



# Create the sample training dataset file
data = {
    "text": [
        "The feedback is that product is good.",
        "Overall feedback of the purchase process is smooth",
        "I have not met with good experience when buying apple products online",
        "would you like to give your feedback ?",
        "I need help setting up my Iphone 4 camera",
        "The iPhone XS Max is too bulky and heavy.",
        "The iPhone X's Face ID can be unreliable in certain lighting conditions.",
        "The iPhone 14's battery life could be better.",
        "The iPhone 13's notch is too big.",
        "Status of my Order ID: 123456789",
        "let me know the status of my Order ID 123456789",
        "Order ID 123233789 Status",
        "Order # 123456881 is getting delivered today",
        "Order ID 123212719 status",
        "status of my order # 213456739 ",
        "what is the status of Order ID 432456790",
        "Love the new Dynamic Island on the iPhone 14 Pro Max!",
        "The iPhone 13's camera is amazing, especially in low light.",
        "The iPhone SE is a great budget-friendly option.",
        "The iPhone 12's design is sleek and durable.",
        "is Order ID 123456986 in delievered status",
        "order Number 123456789",
        "Order ID 123456789",
        "who deliverd my Order # 120001112",
        "The iPhone 11's battery life is impressive.",
        "The iPhone XR's vibrant colors are stunning.",
        "The iPhone XS Max's large display is perfect for watching videos.",
        "The iPhone X's Face ID is incredibly convenient.",
        "my Order ID 378139001 is delivered today",
        "why Order ID 123456789 is not delivered today",
        "status of my Order # 164256709",
        "where does my Order Id 987456289 reached",
        "who delivered my Order id 123456192",
        "order # 123456432",
        "order id 123234289",
        "Order Number 123456789",
         "Love the new iPhone 15 Pro Max, the camera is amazing!",
          "AirPods Pro (2nd gen) are a game-changer for noise cancellation.",
          "The new iPad mini is super portable and powerful.",
          "The Apple Watch Ultra is a rugged and durable smartwatch.",
          "The Mac Studio is a powerhouse for creative professionals.",
          "The HomePod mini delivers great sound quality.",
          "Disappointed with the battery life of the new iPhone.",
          "The AirPods Pro (2nd gen) are uncomfortable for long wear.",
          "The MacBook Air M2 gets hot under heavy load.",
          "The Apple Watch Series 8 has inaccurate heart rate tracking.",
          "The iPad Pro is too expensive for the average consumer.",
          "The iPhone 14 has a lower resolution display than the previous model.",
          "The iPad mini's battery life could be better.",
          "The Apple Watch Ultra is too bulky for everyday wear.",
          "The Mac Studio is overpriced for its performance.",
          "The HomePod mini lacks bass.",
          "The iPhone 14 Pro Max's Dynamic Island is a game-changer.",
          "How do I set up my new iPhone?",
          "How do I set up my new iPad?",
          "How do I set up my new MacBook?",
          "How do I set up my new Apple Watch?",

          "The MacBook Air M2 is incredibly fast and lightweight.",
          "The Apple Watch Series 8 is a great fitness tracker.",
          "The iPad Pro is perfect for work and entertainment.",
          "The iPhone 14 is a great value for the price.",
          "How do I set up my new AirPods?",
          "What are the steps to set up Face ID on my iPhone?",
          "How can I connect my AirPods to my MacBook?",
          "What do I need to do to set up iCloud backup?",
          "How do I enable two-factor authentication on my Apple ID?",
          "Please guide me on setting up Siri on my iPhone.",
          "Can you help me set up a new Apple ID?",
          "I need help setting up my Apple Watch.",
          "Please show me how to set up Family Sharing",
          "How do I set up my new HomePod?",
          "How do I set up two-factor authentication on my Apple ID?",
          "How do I set up iCloud backup?",
          "How do I set up Apple Pay?",
          "How do I set up Family Sharing?",
          "What are the steps involved in setting up a new Apple TV?",
          "Could you explain how to set up HomeKit on my HomePod?",
          "What do I need to do to transfer data from my old iPhone to my new one?",
          "Can you guide me on setting up a VPN on my Mac?",
          "I'm having trouble setting up my new iPad.",
          "I can't connect my AirPods to my Mac.",
          "My iPhone won't recognize my Apple Watch.",
          "I'm having issues setting up iCloud backup.",
          "where is my Order ID 378009001",
          "can i know the status of my Order ID 100456789",
          "where is my Order # 164256709",
          "The iPhone SE (3rd generation) lacks advanced features.",
          "The iPhone 12's ceramic shield is fragile.",
          "i would like to know the status of Order Id 980056289",
          "why my Order id 123456192 is delayed",
          "my Order ID 370039001 was delivered yesterday",
          "could you please let me know the status of Order ID 120056789 ?",
          "The iPhone 11's performance is slowing down.",
          "The iPhone XR's camera quality is not as good as newer models.",
          "Order # 164200709 is delivered",
          "Order Id 909456289 is delayed",
          "Order id 123456192 in transit",
          "The new MacBook Pro's M2 chip is incredibly powerful.",
          "The Apple Watch Series 8's blood oxygen monitoring feature is impressive.",
          "The iPad Air (5th generation) is a great value for the price.",
          "The iPhone 13's battery life is disappointing.",
          "The MacBook Pro's keyboard is prone to failure.",
          "Yes, My feedback about the product is that it is exceptional",
          "The feedback is camera does not work some times",
          "I like the product and rate this to 4 star",
        "what could be improved in the overall process or any product ?",
        "the camera does very well, but the zoom feature can be improved.",
        "what is your feedback on the product ? would you like to recommend it ?",
        "How do I enable Do Not Disturb on my iPhone 12?",
"My iPhone is stuck on the Apple logo. What should I do?",
"How do I set up Siri on my iPhone 14?",
"Can you guide me on setting up a VPN on my iPhone?",
        "Can you help me transfer data from my old iPhone to my new iPhone 15?",
"How do I use the Dynamic Island on my iPhone 14 Pro Max?",
"I'm having trouble setting up Apple Pay on my iPhone SE.",
"What is the process of setting up iCloud backup?",

"What is the status of my order?",
"When will my order be shipped?",
"When will my order arrive?",
"Where is my order?",
"What is the tracking number for my order?",
"Is my order on backorder?",
"Has my order shipped yet?",
"When can I expect my order to be delivered?",
"What is the estimated delivery time for my order?",
"Is there a delay in my order?",
"How do I cancel my order?",
"Can I return my order?",
"What is the return policy?",
"How do I initiate a return?",
"What is the return shipping address?",
"What payment methods do you accept?",
"How do I pay for my order?",
"Can I change the payment method for my order?",
"When will my credit card be charged?",
"I have not received a confirmation email for my order.",
"Can I change the shipping address for my order?",
"Can I add items to my order?",
"Can I remove items from my order?",
"Can I change the quantity of items in my order?",
"I have a question about my order.",
"I need help with my order.",
"I have a problem with my order.",
"I need to contact customer support.",
"How can I reach customer support?",
"What is the status of order number 12345?",
"Is my order number 67890 shipped yet?",
"When can I expect delivery for order number 98765?",
"Is there a delay in order number 45678?",
"Can you track my order number 32109?",
"I haven't received a shipping confirmation email.",
"My order is showing as delivered, but I haven't received it.",
"I ordered the wrong item. How do I return it?",
"Can I exchange an item in my order?",
"What is the order status of my recent purchase?",
"I need to update my shipping address.",
"Can I split my order into multiple shipments?",
"Can I combine multiple orders into one shipment?",
"What is the estimated delivery time for international orders?",
"How do I track my international order?",
"Can I get a refund for a canceled order?",
"How do I check the order history on your website?",
"Can I modify the billing address for my order?",
"What is the estimated processing time for my order?",
"Can I get a discount on my next order?",
"What is the return policy for digital products?",
"When will my order be out for delivery?",
"Can I schedule a specific delivery date and time?",
"Is there a delivery window for my order?",
"Can I track my order using a specific tracking link?",
"What is the reason for the delay in my order?",
"Is there any update on my delayed order?",
"Can I collect my order from a nearby store?",
"Can I get a notification when my order is out for delivery?",
"Can I request a signature confirmation for my delivery?",
"What are the delivery charges for my order?",
"Can I get a refund for shipping charges if my order is delayed?",
"What is the cutoff time for same-day delivery?",
"Can I get a refund for a lost package?",
"What happens if I refuse the delivery?",
"Can I change the delivery address after placing the order?",
"What is the status of my international order?",
"How long does international shipping take?",
"What are the customs duties and taxes for international orders?",
"Can I track my international order using a specific tracking link?",
"What is the process for a missed delivery?",
"Can I reschedule a missed delivery?",
"What is the process for a failed delivery attempt?",
"Can I request a redelivery?",
"Can I get a refund for a failed delivery attempt?",
"What is the insurance coverage for my order?",
"Can I insure my order for additional coverage?",
"What happens if my order is damaged during shipping?",
"How do I report a damaged or missing item in my order?",
"What is the process for a product recall or safety notice?",
"Can I get a replacement for a damaged or defective product?",
"What is the warranty period for my order?",
"How can I claim the warranty for my order?",
"Can I extend the warranty period for my order?",
"What is the process for a product exchange?",
"Can I exchange a product for a different size or color?",
"Can I exchange a product for a different product?",
"What is the process for a price match?",
"Can I get a price adjustment for a recent price drop?",
"Can I return a gift item?",
"What is the return policy for personalized items?",
"How do I track the status of my return?",
"When will I receive a refund for my returned item?",
"Can I return an item purchased on sale?",
"What is the return policy for clearance items?",
"Can I return an item without a receipt?",
"Can I exchange an item for a different size or color?",
"How do I contact customer support for order-related issues?",
"What is the status of my backordered item?",
"Can I request a partial refund for a damaged item?",
"What is the estimated processing time for a custom order?",
"Can I get a discount on a bulk order?",
"How do I track my international order?",
"What are the customs duties and taxes for international orders?",
"Can I get a gift receipt for my order?",
"How do I return a gift item?",
"What is the warranty period for my order?",
"How can I check the order status on your app?",
"Can I modify the delivery address for my order?",
"Can I get a delivery confirmation email?",
"What happens if I am not home during delivery?",
"Can I request a specific delivery time slot?",
"Can I pay cash on delivery?",
"What are the charges for shipping and handling?",
"Can I return an item after delivery?",
"What is the process for a replacement order?",
"Can I get a refund for a delayed order?",
"How can I contact customer support for order updates?",
"What is the status of my pre-order?",
"Can I cancel a pre-order?",
"Can I modify a pre-order?",
"What is the expected shipping time for pre-orders?",
"Can I get a discount on pre-orders?",
"How can I track my pre-order?",
"What is the estimated shipping time for bulk orders?",
"Can I get a discount for bulk orders?",
"How can I combine multiple orders into one shipment?",
"Can I split a large order into multiple shipments?",
"What is the status of my subscription order?",
"Can I track my order on your website?",
"What is the estimated delivery time for my order?",
"Is my order eligible for expedited shipping?",
"Can I change the shipping address for my order?",
"My order has not arrived yet. What should I do?",
"I received a damaged item. How can I return it?",
"I received the wrong item. How can I exchange it?",
"Can I return an item without a receipt?",
"What is your return policy?",
"How long does it take to process a return?",
"When will I receive a refund for my returned item?",
"The iPhone 15 Pro Max is a stunning device, but the battery life could be better.",
"The new MacBook Air is sleek and powerful, but the screen could be brighter.",
"The iPad Pro is a fantastic tablet, but it's a bit too expensive.",
"The Apple Watch Series 8 is a great fitness tracker, but the battery life could be improved.",
"The AirPods Pro are amazing for noise cancellation, but they can be uncomfortable for long periods.",
"The HomePod mini is a great little speaker, but it lacks bass.",
"The Apple TV 4K is a fantastic streaming device, but the remote could be better designed.",
"The Mac Studio is a powerful machine, but it's very expensive.",
"The iPhone 13 is a great value for the price, but the camera could be better in low-light conditions.",
"The iPad Air is a great tablet for everyday use, but it lacks the power of the iPad Pro.",
"The Apple Watch SE is a good budget-friendly option, but it lacks some features of the higher-end models.",
"The MacBook Air M1 is a great laptop for everyday tasks, but it can struggle with heavy workloads.",
"The iPhone 12 is a beautiful phone, but the battery life could be improved.",
"The iPhone 11 is a good value for the price, but the camera could be better in low-light conditions.",
"The iPhone XS Max is a great phone, but it's very expensive.",
"The iPhone X is a great phone, but the battery life could be better.",
"The iPad Pro is a great tablet for productivity, but it's heavy and bulky.",
"The iPad Air is a great tablet for everyday use, but it lacks the power of the iPad Pro.",
"The iPad mini is a great portable tablet, but the screen is small.",
"The MacBook Pro is a great laptop for professionals, but it's expensive.",
"The MacBook Air is a great laptop for students and casual users, but it's not as powerful as the MacBook Pro.",
"The iMac is a great desktop computer, but it's expensive.",
"The Mac mini is a great compact computer, but it requires external peripherals.",
"The Apple Watch Series 7 is a great smartwatch, but it's expensive.",
"The Apple Watch SE is a good budget-friendly smartwatch, but it lacks some features of the higher-end models.",
"The AirPods Pro are great for noise cancellation, but they can be uncomfortable for long periods.",
"The AirPods (3rd generation) are a good value for the price, but they lack some features of the AirPods Pro.",
"The HomePod mini is a great little speaker, but it lacks bass.",
"The HomePod is a great speaker, but it's expensive.",
"The Apple TV 4K is a great streaming device, but the remote could be better designed.",
"The Apple TV HD is a good budget-friendly streaming device, but it lacks some features of the Apple TV 4K.",
"The Apple TV is a great media streaming device, but it's expensive.",
"The Apple Pencil is a great stylus, but it's expensive.",
"The Magic Keyboard is a great keyboard, but it's expensive.",
"The Magic Mouse is a great mouse, but it's not ergonomic.",
"The Magic Trackpad is a great trackpad, but it's expensive.",
"The Apple Store experience is great, but the prices are high.",
"The Apple website is easy to use, but it can be slow.",
"Apple customer service is great, but it can be difficult to reach a real person.",
"Apple products are well-designed and high-quality, but they are expensive.",
"Apple updates are frequent and reliable, but they can be disruptive.",
"Apple's privacy policies are strong, but they can be restrictive.",
"Apple's ecosystem is convenient, but it can be limiting.",
"Apple products are innovative, but they can be ahead of their time.",
"Apple products are reliable, but they can be expensive to repair.",
"Apple products are stylish, but they can be fragile.",
"Apple products are easy to use, but they can be complex to set up.",
"Apple products are compatible with other Apple devices, but they can be incompatible with other devices.",
"Apple products are often imitated, but they are still the best.",
"Apple products are worth the price, but they can be expensive.",
"Apple products are a status symbol, but they are also functional.",
"Apple products are a good investment, but they can be expensive.",
"Apple products are reliable and durable, but they can be expensive to repair.",
"Apple products are innovative and cutting-edge, but they can be complex to use.",
"Apple products are easy to use, but they can be limited in functionality.",
"Apple products are well-designed and aesthetically pleasing, but they can be expensive.",
"Apple products are eco-friendly, but they can be expensive.",
"Apple products are reliable and trustworthy, but they can be expensive.",
"Online Ordering and Delivery Experience:",
"The Apple online store is easy to navigate and user-friendly.",
"The checkout process is quick and easy.",
"Shipping is fast and reliable.",
"Packaging is excellent and protects the product well.",
"Delivery updates are timely and accurate.",
"The estimated delivery time is usually accurate.",
"The option to pick up orders from the Apple Store is convenient.",
"The in-store pickup process is quick and efficient.",
"The customer service representatives are knowledgeable and helpful.",
"The return process is easy and hassle-free.",
"The refund process is quick and efficient.",
"Apple's warranty and repair services are excellent.",
"Apple's trade-in program is convenient and offers fair value.",
"The Apple Store experience is excellent, with knowledgeable and helpful staff.",
"The Apple Store is well-stocked and organized.",
"The Apple Store offers a great shopping experience.",
"How do I set up a new iPhone?",
"How do I transfer data from my old iPhone to my new one?",
"How do I set up Face ID on my iPhone?",
"How do I set up Touch ID on my iPhone?",
"How do I set up Apple Pay on my iPhone?",
"How do I set up iCloud on my iPhone?",
"How do I set up Wi-Fi and Bluetooth on my iPhone?",
"How do I set up Siri on my iPhone?",
"How do I set up Mail on my iPhone?",
"How do I set up Calendar on my iPhone?",
"How do I set up Contacts on my iPhone?",
"How do I set up Notes on my iPhone?",
"How do I set up Reminders on my iPhone?",
"How do I set up the Clock app on my iPhone?",
"How do I set up the Weather app on my iPhone?",
"How do I set up the Maps app on my iPhone?",
"How do I set up the App Store on my iPhone?",
"How do I set up iTunes on my iPhone?",
"How do I set up FaceTime on my iPhone?",
"How do I set up Messages on my iPhone?",
"My iPhone won't turn on. What should I do?",
"My iPhone is stuck on the Apple logo. How do I fix it?",
"My iPhone's battery is draining too fast. What can I do?",
"My iPhone's screen is unresponsive. How do I fix it?",
"My iPhone is not recognizing my SIM card. What should I do?",
"My AirPods won't connect to my iPhone. How do I fix it?",
"My Apple Watch won't pair with my iPhone. What should I do?",
"My iPhone is overheating. What should I do?",
"My iPhone's camera is not working properly. What should I do?",
"My iPhone's microphone is not working properly. What should I do?",
"My iPhone's speaker is not working properly. What should I do?",
"My iPhone's Wi-Fi is not working properly. What should I do?",
"My iPhone's Bluetooth is not working properly. What should I do?",
"My iPhone's cellular data is not working properly. What should I do?",
"My iPhone's GPS is not working properly. What should I do?",
"My iPhone's Face ID is not working properly. What should I do?",
"My iPhone's Touch ID is not working properly. What should I do?",
"My iPhone's screen is cracked. What should I do?",
"My iPhone's screen is scratched. What should I do?",
"My iPhone's back glass is cracked. What should I do?",
"My iPhone's charging port is damaged. What should I do?",
"My iPhone's headphone jack is not working. What should I do?",
"My iPhone's speakers are distorted. What should I do?",
"My iPhone's microphone is picking up noise. What should I do?",
"My iPhone's camera is blurry. What should I do?",
"My iPhone's camera app is crashing. What should I do?",
"My iPhone's photos are not syncing to iCloud. What should I do?",
"My iPhone's videos are not playing properly. What should I do?",
"My iPhone's apps are crashing. What should I do?",
"My iPhone's battery is not charging properly. What should I do?",
"My iPhone's battery is not holding a charge. What should I do?",
"My iPhone's screen is flickering. What should I do?",
"My iPhone's screen is dim. What should I do?",
"My iPhone's screen is unresponsive to touch. What should I do?",
"My iPhone's keyboard is not working properly. What should I do?",
"My iPhone's voice recognition is not working properly. What should I do?",
"My iPhone's notifications are not working properly. What should I do?",
"My iPhone's alarms are not working properly. What should I do?",
"My iPhone's clock is not accurate. What should I do?",
"My iPhone's date and time settings are incorrect. What should I do?",
"My iPhone's software is not updating properly. What should I do?",
"My iPhone's apps are not updating properly. What should I do?",
"My iPhone is not syncing with my Mac. What should I do?",
"My iPhone is not syncing with my iPad. What should I do?",
"My iPhone is not syncing with my Apple Watch. What should I do?",
"My iPhone is not syncing with my iCloud account. What should I do?",
"What's the best way to set up my new iPhone?",
"How can I transfer my data from my old iPhone to my new one?",
"What's the process to set up Face ID on my iPhone?",
"How do I enable Touch ID on my iPad?",
"How can I set up Apple Pay?",
"What are the steps to set up iCloud?",
"How do I connect my iPhone to Wi-Fi and Bluetooth?",
"How do I activate Siri on my iPhone?",
"What's the process to set up my email account on my iPhone?",
"How do I set up my calendar on my iPhone?",
"How do I sync my contacts to my iPhone?",
"How do I use the Notes app on my iPhone?",
"How do I set up reminders on my iPhone?",
"How do I use the Clock app on my iPhone?",
"How do I use the Weather app on my iPhone?",
"How do I use the Maps app on my iPhone?",
"How do I download apps from the App Store?",
"How do I use iTunes on my computer?",
"How do I make FaceTime calls?",
"How do I send messages using the Messages app?",
"My iPhone won't turn on. What should I do?",
"My iPhone is stuck on the Apple logo. How can I fix it?",
"Why is my iPhone's battery draining so quickly?",
"My iPhone's screen is unresponsive. What can I do?",
"My iPhone isn't recognizing my SIM card. What's the issue?",
"My AirPods won't connect to my iPhone. How can I fix this?",
"My Apple Watch won't pair with my iPhone. What should I do?",
"My MacBook won't turn on. What's wrong?",
"My MacBook's trackpad isn't working. How can I fix it?",
"My MacBook's keyboard isn't working. What should I do?",
"My Mac is running slow. How can I speed it up?",
"My Mac isn't recognizing my external hard drive. What's the problem?",
"My Mac won't connect to the internet. What should I do?",
"My iPad won't turn on. What's wrong?",
"My iPad's screen is cracked. How can I fix it?",
"My iPad's battery is draining too quickly. What should I do?",
"My iPad isn't recognizing my Apple Pencil. What's the issue?",
"My iPad won't connect to Wi-Fi. What can I do?",
"My HomePod won't connect to Wi-Fi. How can I fix this?",
"My HomePod isn't responding to voice commands. What should I do?",
"How do I use Face ID?",
"How do I set up Touch ID?",
"How do I use Apple Pay?",
"How do I use Siri?",
"How do I use Night Shift?",
"How do I use Do Not Disturb?",
"How do I use Screen Time?",
"How do I use Find My iPhone?",
"How do I use iCloud Backup?",
"How do I use iCloud Photo Library?",
"How do I use iCloud Drive?",
"How do I use Apple Music?",
"How do I use Apple TV+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use the Camera app?",
"How do I use the Photos app?",
"How do I use the Notes app?",
"How do I use the Reminders app?",
"How do I use the Calendar app?",
"How do I update my iPhone's software?",
"How do I update my iPad's software?",
"How do I update my Mac's software?",
"How do I back up my iPhone?",
"How do I restore my iPhone from a backup?",
"How do I recover deleted files from my iPhone?",
"How do I troubleshoot Bluetooth connectivity issues?",
"How do I troubleshoot Wi-Fi connectivity issues?",
"How do I fix a slow iPhone?",
"How do I fix a frozen iPhone?",
"How do I fix a broken iPhone screen?",
"How do I fix a cracked iPhone screen?",
"How do I replace an iPhone battery?",
"How do I clean my iPhone screen?",
"How do I protect my iPhone from water damage?",
"How do I protect my iPhone from scratches?",
"How do I set up parental controls on my iPhone?",
"How do I use Screen Time to limit screen time?",
"How do I use Family Sharing?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"How do I use Apple Books?",
"How do I use Apple Podcasts?",
"How do I use Apple TV+?",
"How do I use Apple Music?",
"How do I use Apple Maps?",
"How do I use Apple Wallet?",
"How do I use Apple Pay Cash?",
"How do I use Apple Card?",
"How do I use Apple Fitness+?",
"How do I use Apple Music Fitness+?",
"How do I use Apple Arcade?",
"How do I use Apple News+?",
"My iPhone won't turn on.",
"My iPhone is stuck on the Apple logo.",
"My iPhone's battery drains too quickly.",
"My iPhone's screen is unresponsive.",
"My iPhone isn't recognizing my SIM card.",
"My AirPods won't connect to my iPhone.",
"My Apple Watch won't pair with my iPhone.",
"My iPhone is overheating.",
"My iPhone's camera isn't working properly.",
"My iPhone's microphone isn't working properly.",
"My iPhone's speaker is distorted.",
"My iPhone's Wi-Fi is unstable.",
"My iPhone's Bluetooth is disconnecting frequently.",
"My iPhone's cellular data is slow or not working.",
"My iPhone's GPS is inaccurate.",
"Face ID isn't working on my iPhone.",
"Touch ID isn't working on my iPhone."


    ],
    "label": [
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "product_setup",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
              "order_id_status",
              "order_id_status",
              "order_id_status",
              "feedback",
              "feedback",
                            "feedback",
              "feedback",
              "feedback",
               "feedback",
              "feedback",
              "feedback",
              "feedback",
               "feedback",
              "feedback",
              "feedback",
              "feedback",
               "feedback",
              "feedback",
              "feedback",
              "feedback",
               "feedback",
              "feedback",
              "order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup"
              ]
}


num_elements = len(data["text"])
print(num_elements)

num_values = len(data["label"])
print(num_values)

df = pd.DataFrame(data)
df.to_csv("sample_dataset.csv", index=False)

# Create the sample test dataset file
test_data = {
    "text": [
        "Yes, i would you like to give feedback.",
        "No, i would not like to give feedback.",
        "Could you give us rating from 1 to 5 ?",
        "I rate this product to 1",
        "Order ID: 123456789",
        "The AirPods Max offer exceptional sound quality.",
        "The Apple TV 4K is a great streaming device.",

        "what is the satus of my Order # 123456881",
        "where is my Order ID 123212719",
        "Order ID 765436789 is delivered",
        "Order # 332211789 delayed too much",
        "Order ID 987654789 in transit",

        "The iPhone 13's night mode is amazing.",
        "The MacBook Pro's Touch Bar is a convenient feature.",
        "The Apple Watch SE is a budget-friendly option.",
        "The iPad mini is perfect for reading and browsing the web.",
        "The iPhone 14 Pro Max is too expensive.",
        "The MacBook Pro's battery life could be better.",
        "The Apple Watch Series 8 is not very accurate in tracking workouts.",
        "The iPad Air (5th generation) is not as powerful as the iPad Pro.",

        "Could you explain how to set up iCloud Keychain?",
        "Can you guide me on setting up Find My on my iPhone?",
        "How do I pair my AirPods Pro with my iPhone 15?",
        "What are the steps to set up Apple Pay on my Apple Watch Series 9?",

        "The AirPods Max are too bulky and uncomfortable.",
        "The Apple TV 4K remote is difficult to use.",
        "The Apple Watch SE lacks advanced features.",
        "The iPad mini's screen is too small for serious work.",

        "How do I set up Face ID on my iPhone?",
        "How do I set up Touch ID on my iPad?",
        "How do I set up Siri on my iPhone?",
        "Please help me set up two-factor authentication on my Apple ID.",
        "i need help with iphone 12 camera set up",
        "Can you guide me through the process of setting up Screen Time on my iPad?",
        "I'm having trouble setting up FaceTime on my Mac.",
        "My Apple Watch is not syncing with my iPhone.",
        "I can't connect my iPad to my Wi-Fi network.",
        "How do I set up Face ID on my iPhone 14 Pro?.",
        "My iPhone 13 is not connecting to Wi-Fi.",

        "What payment methods do you accept?",
"Can I pay with a credit card?",
"Can I pay with PayPal?",
"Can I pay with Apple Pay?",
"Can I pay with a debit card?",
"Can I pay with cash on delivery?",
"When will my credit card be charged?",
"I have not received a confirmation email for my order.",
"Can I change the payment method for my order?",
"Can I modify the billing address for my order?",
"What is the current status of my order with order number [Order Number]?",
"When can I expect my order to be delivered?",
"Can you provide a tracking number for my order?",
"Where is my order currently located?",
"Has my order shipped yet?",
"Is there a delay in the shipping of my order?",
"Can I cancel my order?",
"Can I modify my order?",
"Can I add items to my order?",
"Can I remove items from my order?",
"Can I change the quantity of items in my order?",
"What is the status of my backordered item?",
"When will my backordered item be available?",
"Can I cancel a backordered item?",
"Can I substitute a backordered item with a similar product?",
"What are the shipping costs for my order?",
"Is there free shipping on my order?",
"What are the available shipping carriers for my order?",
"Can I choose a specific shipping carrier?",
"Can I specify a delivery date or time window?",
"Can I pick up my order from a store?",
"Is there a store pickup option available?",
"What are the store pickup hours?",
"Can I pay for my order upon delivery?",
"What happens if I am not home during delivery?",
"Can I request a specific delivery person?",
"What is the estimated delivery time for my pin code?",
"Can I track my order by SMS?",
"Can I expedite my order?",
"What is the shipping carrier for my order?",
"Can I track my order using a different tracking number?",
"Can I split a large order into multiple shipments?",
"Can I combine multiple orders into one shipment?",
"What is the estimated delivery time for international orders?",
"How do I track my international order?",
"What are the customs duties and taxes for international orders?",
"What is the status of my order?",
"When will my order be shipped?",
"When will my order arrive?",
"Where is my order?",
"What is the tracking number for my order?",
"Is my order on backorder?",
"Has my order shipped yet?",
"When can I expect my order to be delivered?",
"What is the estimated delivery time for my order?",
"Is there a delay in my order?",
"How do I cancel my order?",
"Can I return my order?",
"What is the return policy?",
"How do I initiate a return?",
"What is the return shipping address?",
"What payment methods do you accept?",
"How do I pay for my order?",
"Can I change the payment method for my order?",
"When will my credit card be charged?",
"I have not received a confirmation email for my order.",
"Can I change the shipping address for my order?",
"Can I add items to my order?",
"Can I remove items from my order?",
"Can I change the quantity of items in my order?",
"I have a question about my order.",
"I need help with my order.",
"I have a problem with my order.",
"I need to contact customer support.",
"How can I reach customer support?",
"What is the status of order number 12345?",
"Is my order number 67890 shipped yet?",
"When can I expect delivery for order number 98765?",
"Is there a delay in order number 45678?",
"Can you track my order number 32109?",
"I haven't received a shipping confirmation email.",
"My order is showing as delivered, but I haven't received it.",
"I ordered the wrong item. How do I return it?",
"Can I exchange an item in my order?",
"What is the order status of my recent purchase?",
"I need to update my shipping address.",
"Can I split my order into multiple shipments?",
"Can I combine multiple orders into one shipment?",
"What is the estimated delivery time for international orders?",
"How do I track my international order?",
"Can I get a refund for a canceled order?",
"How do I check the order history on your website?",
"Can I modify the billing address for my order?",
"What is the estimated processing time for my order?",
"Can I get a discount on my next order?",
"What is the return policy for digital products?",
"Can I expedite my order?",
"What is the shipping carrier for my order?",
"Can I track my order using a different tracking number?",
"I received a damaged item. What should I do?",
"I received the wrong item. How do I return it?",
"I received a defective item. Can I get a replacement?",
"Can I change the color or size of my order?",
"Can I gift wrap my order?",
"What are the payment options available?",
"Can I pay for my order with a credit card?",
"Can I pay for my order with PayPal?",
"Can I pay for my order with a debit card?",
"Can I pay for my order with cash on delivery?",
"How can I check my order history?",
"How can I cancel a recurring order?",
"Can I get a refund for a returned item?",
"How long does it take to process a return?",
"Can I return an item without a receipt?",
"What is your return policy for clearance items?",
"Can I exchange an item for a different size or color?",
"How do I contact customer support for order-related issues?",
"What is the status of my backordered item?",
"Can I request a partial refund for a damaged item?",
"What is the estimated processing time for a custom order?",
"Can I get a discount on a bulk order?",
"How do I track my international order?",
"What are the customs duties and taxes for international orders?",
"Can I get a gift receipt for my order?",
"How do I return a gift item?",
"What is the warranty period for my order?",
"When will my order be dispatched?",
"Can I track my order by SMS?",
"What is the estimated delivery time for my pin code?",
"Can I pick up my order from a store?",
"Is there any delay in shipments due to holidays?",
"Can I reschedule my delivery?",
"What is the cut-off time for same-day delivery?",
"Can I get an invoice for my order?",
"The Apple Store's Genius Bar is a great resource for troubleshooting and repairs.",
"Apple's online support is helpful and informative.",
"Apple's community forums are a great place to get help and advice.",
"Apple's software updates are frequent and reliable.",
"Apple's security features are strong and effective.",
"Apple's privacy policies are transparent and user-friendly.",
"Apple's customer support is responsive and helpful.",
"Apple's warranty coverage is comprehensive.",
"Apple's repair services are efficient and affordable.",
"Apple's trade-in program is a great way to upgrade to a new device.",
"Apple's recycling program is environmentally friendly.",
"Apple's packaging is minimal and eco-friendly.",
"Apple's commitment to sustainability is commendable.",
"Apple's products are designed to last.",
"Apple's products are easy to use and intuitive.",
"Apple's products are innovative and cutting-edge.",
"Apple's products are reliable and durable.",
"Apple's products are a good value for the price.",
"Apple's products are a status symbol.",
"Apple's products are a great gift for loved ones.",
"Apple's products are a great investment.",
"Apple's products are compatible with other Apple devices.",
"Apple's products are easy to set up and use.",
"Apple's products are well-designed and aesthetically pleasing.",
"Apple's products are eco-friendly.",
"Apple's products are reliable and trustworthy.",
"My iPhone screen is cracked.",
"My iPhone screen is scratched.",
"My iPhone's back glass is broken.",
"My iPhone's charging port is damaged.",
"My iPhone's headphone jack isn't working.",
"My iPhone's speakers sound distorted.",
"My iPhone's microphone picks up background noise.",
"My iPhone's camera photos are blurry.",
"My iPhone's camera app keeps crashing.",
"My iPhone photos aren't syncing to iCloud.",
"My iPhone videos won't play properly.",
"My iPhone apps keep crashing.",
"My iPhone battery isn't charging properly.",
"My iPhone battery drains too quickly.",
"My iPhone screen flickers.",
"My iPhone screen is dim.",
"My iPhone screen is unresponsive to touch.",
"My iPhone keyboard isn't working properly.",
"My iPhone's voice recognition isn't accurate.",
"My iPhone notifications aren't working properly.",
"My iPhone alarms aren't going off.",
"My iPhone's clock is incorrect.",
"My iPhone's date and time settings are wrong.",
"My iPhone software won't update.",
"My iPhone apps won't update.",
"My iPhone won't sync with my Mac.",
"My iPhone won't sync with my iPad.",
"My iPhone won't sync with my Apple Watch.",
"My iPhone won't sync with my iCloud account.",
"I'm having issues with Apple Pay.",
"I'm having issues with Apple Music.",
"I'm having issues with Apple TV+.",
"I'm having issues with Apple Arcade.",
"I'm having issues with Apple News+.",
"I'm having issues with Apple Books.",
"I'm having issues with Apple Podcasts.",
"I'm having issues with Apple Maps.",
"I'm having issues with Apple Wallet.",
"I'm having issues with Siri.",
"I'm having issues with Face ID.",
"I'm having issues with Touch ID.",
"I'm having issues with the Camera app.",
"I'm having issues with the Photos app.",
"I'm having issues with the Notes app.",
"I'm having issues with the Reminders app.",
"I'm having issues with the Calendar app.",
"I'm having issues with the Clock app.",
"I'm having issues with the Weather app.",
"I'm having issues with the Mail app.",
"I'm having issues with the Messages app.",
"I'm having issues with the Safari app.",
"I'm having issues with the Settings app.",
"I'm having issues with the App Store.",
"I'm having issues with iTunes.",
"I'm having issues with iCloud.",
"I'm having issues with FaceTime.",
"I'm having issues with Messages.",
"I'm having issues with Screen Time.",
"I'm having issues with Do Not Disturb.",
"I'm having issues with Night Shift.",
"I'm having issues with True Tone.",
"I'm having issues with Dark Mode.",
"I'm having issues with AirPods.",
"I'm having issues with Apple Watch.",
"I'm having issues with HomeKit.",
"I'm having issues with Apple TV.",
"I'm having issues with Apple Pencil.",
"I'm having issues with Magic Keyboard.",
"I'm having issues with Magic Mouse.",
"I'm having issues with Magic Trackpad.",
"I'm having issues with AppleCare+.",
"I'm having issues with Apple Support.",
"I'm having issues with Apple Store appointments.",
"I'm having issues with Apple's website.",
"I'm having issues with Apple's online store.",
"I'm having issues with Apple's trade-in program.",
"I'm having issues with Apple's recycling program.",
"My iPhone's battery drains quickly even with optimized battery settings.",
"My iPhone's camera app crashes frequently.",
"My iPhone's photos are blurry or have poor quality in low light.",
"My iPhone's video recording is unstable or blurry.",
"My iPhone's audio quality is poor during calls.",
"My iPhone's speaker volume is low.",
"My iPhone's screen is unresponsive to touch in certain areas.",
"My iPhone's screen is flickering or has dead pixels.",
"My iPhone's Wi-Fi connection keeps dropping.",
"My iPhone's Bluetooth connection is unstable.",
"My iPhone's cellular data is slow or not working properly.",
"My iPhone's GPS is inaccurate or slow to locate.",
"My iPhone's apps are crashing frequently.",
"My iPhone's battery health is deteriorating rapidly.",
"My iPhone's software updates are not installing correctly.",
"My iPhone is not recognizing my Apple Watch.",
"My iPhone is not syncing with my Mac.",
"My iPhone is not backing up to iCloud.",
"My iPhone is not restoring from a backup."
    ],
    "label": [
              "feedback",
              "feedback",
              "feedback",
              "feedback",
        "order_id_status",
        "feedback",
        "feedback",
        "order_id_status",
        "order_id_status",
        "order_id_status",
        "order_id_status",
        "order_id_status",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "feedback",
              "feedback",
              "feedback",
              "feedback",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
              "product_setup",
                            "product_setup",
              "product_setup",
              "product_setup",
              "order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"order_id_status",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"feedback",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup",
"product_setup"
    ]
}

num_elements = len(test_data["text"])
print(num_elements)

num_values = len(test_data["label"])
print(num_values)

def shuffle_csv(file_path, output_file_path):
  df = pd.read_csv(file_path)
  df = df.sample(frac=1).reset_index(drop=True)
  df.to_csv(output_file_path, index=False)


test_df = pd.DataFrame(test_data)
test_df.to_csv("sample_test_dataset.csv", index=False)


input_file_path = "sample_test_dataset.csv"
output_file_path = "shuffled_sample_test_dataset.csv"
shuffle_csv(input_file_path, output_file_path)


input_file_path = "sample_dataset.csv"
output_file_path = "shuffled_sample_dataset.csv"
shuffle_csv(input_file_path, output_file_path)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# 630
# 630
# 295
# 295

# %%
# Load the training dataset
df = pd.read_csv("shuffled_sample_dataset.csv")
dataset = Dataset.from_pandas(df)

# Load the test dataset
test_df = pd.read_csv("shuffled_sample_test_dataset.csv")
test_dataset = Dataset.from_pandas(test_df)

# Define custom labels
labels = ["order_id_status", "feedback", "product_setup"]
label2id = {label: i for i, label in enumerate(labels)}
id2label = {i: label for i, label in enumerate(labels)}

print(label2id)

print ("ID TO LABEL")
print(id2label)

# Map labels to IDs
def encode_labels(example):
    example['label'] = label2id[example['label']]
    return example

dataset = dataset.map(encode_labels)
test_dataset = test_dataset.map(encode_labels)

# Tokenize the dataset
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

def preprocess_function(examples):
    return tokenizer(examples['text'], truncation=True, padding=True)

tokenized_dataset = dataset.map(preprocess_function, batched=True)
tokenized_test_dataset = test_dataset.map(preprocess_function, batched=True)

# Load pre-trained model
model = AutoModelForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels=len(labels),
    id2label=id2label,
    label2id=label2id
)
"""
# Define training arguments
#training_args = TrainingArguments(
    output_dir='./finetuned-v2',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=12,
    num_train_epochs=3,
    weight_decay=0.01,
)
"""

# Define training arguments
training_args = TrainingArguments(
    output_dir='./finetuned-v3',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=14,
    per_device_eval_batch_size=10,
    num_train_epochs=4,
    weight_decay=0.01,
)

# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_test_dataset,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained("./finetuned-v3")
tokenizer.save_pretrained("./finetuned-v3")

# Evaluate the model
results = trainer.evaluate()
print(results)
# Out:
# {'order_id_status': 0, 'feedback': 1, 'product_setup': 2}
# ID TO LABEL
# {0: 'order_id_status', 1: 'feedback', 2: 'product_setup'}
# ...
# Map:   0%|          | 0/295 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...
# Map:   0%|          | 0/295 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, pipeline
import torch
from huggingface_hub import login

login(token="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")

model = AutoModelForSequenceClassification.from_pretrained("./finetuned-v3")
tokenizer = AutoTokenizer.from_pretrained("./finetuned-v3")

model.push_to_hub("dkkh8788/finetuned_classification_model_v3")
tokenizer.push_to_hub("dkkh8788/finetuned_classification_model_v3")

classifier = pipeline("text-classification", model='dkkh8788/finetuned_classification_model_v3',
                      tokenizer='dkkh8788/finetuned_classification_model_v3')

new_texts = [
    "can you tell me status of Order id: 123123111",
    "what is the status of my Order ID: 123456987",
    "I need help setting up my iphone 16?"
]

for text in new_texts:
    res = classifier(text)
    print(res)
    print(f"Text: {text}\nPredicted Label: {res[0]['label']}\n")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# [{'label': 'order_id_status', 'score': 0.9952787160873413}]
# Text: can you tell me status of Order id: 123123111
# ...

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, pipeline
import torch
from transformers import pipeline
from huggingface_hub import InferenceClient

client = InferenceClient(api_key="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")

#classifier = pipeline("text-classification", model='dkkh8788/custom_classification_model_v1',
#                      tokenizer = AutoTokenizer.from_pretrained('dkkh8788/custom_classification_model_v1'))

#classifier = pipeline("text-classification", model='dkkh8788/finetuned_classification_model_v2',
#                      tokenizer='dkkh8788/finetuned_classification_model_v2')

#classifier = pipeline("text-classification", model='dkkh8788/finetuned_classification_model_v1',
#                      tokenizer='dkkh8788/finetuned_classification_model_v1')

classifier = pipeline("text-classification", model='dkkh8788/finetuned_classification_model_v3',
                      tokenizer='dkkh8788/finetuned_classification_model_v3')

def generate_response(feedback, sentiment):

    if sentiment == "POSITIVE":
        prompt = f"Generate an appropriate positive response in 50 words to the customer thanking and expressing gratitude."
    else:
        prompt = f"Generate an appropriate empathetic response in 50 words to the customer apologizing for the inconvenience and offering assistance."

    messages = [
        { "role": "assistant", "content": f"{feedback}\n\nQuestion: {prompt}" },
    ]

    output = client.chat.completions.create(
        model="microsoft/Phi-3.5-mini-instruct",
        messages=messages,
        stream=True,
        temperature=0.5,
        max_tokens=1024,
        top_p=0.7
    )

    # Collect all chunks in a list and join them after the loop
    full_response = []

    for chunk in output:
        full_response.append(chunk.choices[0].delta.content)

    # Join and return the entire response as a single string
    return ("".join(full_response))

def perform_sentiment_analysis(text):
  sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
  result = sentiment_analyzer(text)[0]
  return result['label']

def filter(text, category):
  if category == "feedback":
    sentiment = perform_sentiment_analysis(text)

    # Further process the query based on sentiment
    response = generate_response(text, sentiment)
    print(response)


# Classify new text samples
new_texts = [
    "can you tell me status of Order id: 123123111",
    "what is the status of my Order ID: 123456987",
    "does iphone 10 Pro Max have camera zoom fearues ?",
    "My order with Id: 127865331 was delayed. can i know where it is now ?",
    "latest iphone is just amazing!",
    "i need help with iphone 10 keypad set up",
    "how to set up my iphone 11",
    "is my order id 123987222 status in portal showing transit or delivered ?",
    "the experience with Iphones are best. they have less bugs and works smooth",
    "How can i set up the message forwarding in iphone 12",
    "we loved the purchase. the experience was top notch.",
    "we have not liked the service. it could have been better",
    "the best thing about iphones are the tag they have. i liked it very much.",
    "how to set up the battery in iphone ?",
    "i order iphone 12 on tuesday. my order id is 123999888. could you please update me on the order status ?",
    "can you tell me my order 1234 position ?",
    "Can you tell me my order number 1234 State State",
    "Can you tell me my order number 1 2 3 4 State",
    "My order is 1 2 3 4",
    "1234 status"
]

#for text in new_texts:
for index, text in enumerate(new_texts):
    print("\n\n=======INPUT=======\n\n")
    result = classifier(text)
    output_text = result[0]['label']
    input_text = text
    print(f"Classification Result: {result}")
    print(f"Text: {text}\nPredicted Class: {result[0]['label']}\n")
    filter(input_text, output_text)
# Out:
# =======INPUT=======
#
#
# Classification Result: [{'label': 'order_id_status', 'score': 0.9952787160873413}]
# Text: can you tell me status of Order id: 123123111
# Predicted Class: order_id_status
#
#
#
# =======INPUT=======
#
#
# Classification Result: [{'label': 'order_id_status', 'score': 0.9950529932975769}]
# Text: what is the status of my Order ID: 123456987
# Predicted Class: order_id_status
#
#
#
# =======INPUT=======
#
#
# Classification Result: [{'label': 'feedback', 'score': 0.971822202205658}]
# Text: does iphone 10 Pro Max have camera zoom fearues ?
# Predicted Class: feedback
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-20cd600d0c0c> in <cell line: 90>()
#      95     print(f"Classification Result: {result}")
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
